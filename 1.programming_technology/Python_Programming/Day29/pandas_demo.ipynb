# %%
import pandas as pd

# %%
air_df = pd.read_csv("airlines.csv")

# %%
air_df
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 0       2003/06           6            June       2003
# ...

# %%
air_df.info() #Info of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
air_df.head() # by default print first 5 lines
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
air_df.head(30) #return 30 lines from TOP
# Out:
#    Airport.Code                                       Airport.Name Time.Label  \
# 0           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1           BOS                    Boston, MA: Logan International    2003/06
# 2           BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3           CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4           DCA  Washington, DC: Ronald Reagan Washington National    2003/06
# 5           DEN                   Denver, CO: Denver International    2003/06
# 6           DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...    2003/06
# 7           DTW            Detroit, MI: Detroit Metro Wayne County    2003/06
# 8           EWR           Newark, NJ: Newark Liberty International    2003/06
# 9           FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...    2003/06
# 10          IAD    Washington, DC: Washington Dulles International    2003/06
# ...

# %%
air_df.tail() #By default 5 lines from bottom
# Out:
#      Airport.Code                                      Airport.Name  \
# 4403          SAN            San Diego, CA: San Diego International
# 4404          SEA         Seattle, WA: Seattle/Tacoma International
# 4405          SFO    San Francisco, CA: San Francisco International
# 4406          SLC  Salt Lake City, UT: Salt Lake City International
# 4407          TPA                    Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 4403    2016/01           1         January       2016
# 4404    2016/01           1         January       2016
# 4405    2016/01           1         January       2016
# 4406    2016/01           1         January       2016
# 4407    2016/01           1         January       2016
#
#       Statistics.# of Delays.Carrier  Statistics.# of Delays.Late Aircraft  \
# 4403                             280                                   397
# ...

# %%
air_df.tail(30) #Return 30 lines from bottom
# Out:
#      Airport.Code                                       Airport.Name  \
# 4378          TPA                     Tampa, FL: Tampa International
# 4379          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 4380          BOS                    Boston, MA: Logan International
# 4381          BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 4382          CLT     Charlotte, NC: Charlotte Douglas International
# 4383          DCA  Washington, DC: Ronald Reagan Washington National
# 4384          DEN                   Denver, CO: Denver International
# 4385          DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 4386          DTW            Detroit, MI: Detroit Metro Wayne County
# 4387          EWR           Newark, NJ: Newark Liberty International
# 4388          FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...
# 4389          IAD    Washington, DC: Washington Dulles International
# 4390          IAH  Houston, TX: George Bush Intercontinental/Houston
# ...

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
air_df.loc[1:5] #Rows [start_row : end_row] #End_row is not excluded
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
# 5          DEN                   Denver, CO: Denver International    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
# 5           6            June       2003                             516
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
air_df.iloc[1:3] #iloc fetch by index and loc fetch by index but the assigned one
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 1           6            June       2003                             374
# 2           6            June       2003                             296
#
#    Statistics.# of Delays.Late Aircraft  \
# 1                                   495
# 2                                   477
#
#    Statistics.# of Delays.National Aviation System  \
# 1                                              685
# 2                                              389
#
#    Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 1                                3  ...                        1623
# 2                                8  ...                        1245
#
# ...

# %%
cdf = pd.read_csv("class.csv")

# %%
cdf
# Out:
#                          Timestamp                        Username  \
# 0  2022/04/07 10:24:42 PM GMT+5:30       suvarnasonone60@gmail.com
# 1   2022/04/08 4:37:29 PM GMT+5:30              smoregpp@gmail.com
# 2   2022/04/08 8:43:14 PM GMT+5:30       janghelsakshi08@gmail.com
# 3  2022/04/09 12:43:52 PM GMT+5:30         punekarpayalv@gmail.com
# 4   2022/04/09 2:02:54 PM GMT+5:30  rushikesh26deshpande@gmail.com
# 5   2022/04/09 2:03:44 PM GMT+5:30       snehalpatil1903@gmail.com
# 6   2022/04/09 2:03:51 PM GMT+5:30   priyanka.yethekar11@gmail.com
# 7   2022/04/10 7:42:16 PM GMT+5:30            n.nimesh02@gmail.com
# 8   2022/04/11 8:41:38 PM GMT+5:30        vishwajitdalve@gmail.com
# 9   2022/04/11 8:48:50 PM GMT+5:30           tussharrr.j@gmail.com
#
#                        Name                           Email  Mobile number  \
# 0   Suvarna Tathagat Sonone       suvarnasonone60@gmail.com     7058925952
# 1       More Sweety Rajaram              smoregpp@gmail.com     7721911892
# ...

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      10 non-null     object
#  1   Username       10 non-null     object
#  2   Name           10 non-null     object
#  3   Email          10 non-null     object
#  4   Mobile number  10 non-null     int64
#  5   PRN            10 non-null     int64
#  6   marks          10 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 688.0+ bytes

# %%
cdf.loc[1:4]
# Out:
#                          Timestamp                        Username  \
# 1   2022/04/08 4:37:29 PM GMT+5:30              smoregpp@gmail.com
# 2   2022/04/08 8:43:14 PM GMT+5:30       janghelsakshi08@gmail.com
# 3  2022/04/09 12:43:52 PM GMT+5:30         punekarpayalv@gmail.com
# 4   2022/04/09 2:02:54 PM GMT+5:30  rushikesh26deshpande@gmail.com
#
#                        Name                           Email  Mobile number  \
# 1       More Sweety Rajaram              smoregpp@gmail.com     7721911892
# 2            Sakshi Janghel       janghelsakshi08@gmail.com     8770219283
# 3  Payal Vijaykumar Punekar         punekarpayalv@gmail.com     7741046470
# 4       Rushikesh Deshpande  rushikesh26deshpande@gmail.com     9284180136
#
#             PRN  marks
# 1  220340126016      8
# 2  220340126023      8
# 3  220340126022      9
# 4  220340126008      8

# %%
cdf = pd.read_csv("class.csv",index_col=4)

# %%
cdf
# Out:
#                                      Timestamp  \
# Mobile number
# 7058925952     2022/04/07 10:24:42 PM GMT+5:30
# 7721911892      2022/04/08 4:37:29 PM GMT+5:30
# 8770219283      2022/04/08 8:43:14 PM GMT+5:30
# 7741046470     2022/04/09 12:43:52 PM GMT+5:30
# 9284180136      2022/04/09 2:02:54 PM GMT+5:30
# 8208356103      2022/04/09 2:03:44 PM GMT+5:30
# 9552881797      2022/04/09 2:03:51 PM GMT+5:30
# 9033281629      2022/04/10 7:42:16 PM GMT+5:30
# 8806996936      2022/04/11 8:41:38 PM GMT+5:30
# 7738554123      2022/04/11 8:48:50 PM GMT+5:30
#
#                                      Username                      Name  \
# Mobile number
# 7058925952          suvarnasonone60@gmail.com   Suvarna Tathagat Sonone
# 7721911892                 smoregpp@gmail.com       More Sweety Rajaram
# 8770219283          janghelsakshi08@gmail.com            Sakshi Janghel
# 7741046470            punekarpayalv@gmail.com  Payal Vijaykumar Punekar
# ...

# %%
cdf.loc[7058925952:8208356103]
# Out:
#                                      Timestamp  \
# Mobile number
# 7058925952     2022/04/07 10:24:42 PM GMT+5:30
# 7721911892      2022/04/08 4:37:29 PM GMT+5:30
# 8770219283      2022/04/08 8:43:14 PM GMT+5:30
# 7741046470     2022/04/09 12:43:52 PM GMT+5:30
# 9284180136      2022/04/09 2:02:54 PM GMT+5:30
# 8208356103      2022/04/09 2:03:44 PM GMT+5:30
#
#                                      Username                      Name  \
# Mobile number
# 7058925952          suvarnasonone60@gmail.com   Suvarna Tathagat Sonone
# 7721911892                 smoregpp@gmail.com       More Sweety Rajaram
# 8770219283          janghelsakshi08@gmail.com            Sakshi Janghel
# 7741046470            punekarpayalv@gmail.com  Payal Vijaykumar Punekar
# 9284180136     rushikesh26deshpande@gmail.com       Rushikesh Deshpande
# 8208356103          snehalpatil1903@gmail.com             Snehal Patil
#
#                                         Email           PRN  marks
# Mobile number
# ...

# %%
cdf.iloc[1:3]
# Out:
#                                     Timestamp                   Username  \
# Mobile number
# 7721911892     2022/04/08 4:37:29 PM GMT+5:30         smoregpp@gmail.com
# 8770219283     2022/04/08 8:43:14 PM GMT+5:30  janghelsakshi08@gmail.com
#
#                               Name                      Email           PRN  \
# Mobile number
# 7721911892     More Sweety Rajaram         smoregpp@gmail.com  220340126016
# 8770219283          Sakshi Janghel  janghelsakshi08@gmail.com  220340126023
#
#                marks
# Mobile number
# 7721911892         8
# 8770219283         8

# %%
cdf.shape #Get the shape of dataframe
# Out:
# (10, 6)

# %%
cdf.columns #column names
# Out:
# Index(['Timestamp', 'Username', 'Name', 'Email', 'PRN', 'marks'], dtype='object')

# %%
cdf.index #assigned index
# Out:
# Int64Index([7058925952, 7721911892, 8770219283, 7741046470, 9284180136,
#             8208356103, 9552881797, 9033281629, 8806996936, 7738554123],
#            dtype='int64', name='Mobile number')

# %%
cdf.drop_duplicates() #Returns new dataframe
# Out:
#                                      Timestamp  \
# Mobile number
# 7058925952     2022/04/07 10:24:42 PM GMT+5:30
# 7721911892      2022/04/08 4:37:29 PM GMT+5:30
# 8770219283      2022/04/08 8:43:14 PM GMT+5:30
# 7741046470     2022/04/09 12:43:52 PM GMT+5:30
# 9284180136      2022/04/09 2:02:54 PM GMT+5:30
# 8208356103      2022/04/09 2:03:44 PM GMT+5:30
# 9552881797      2022/04/09 2:03:51 PM GMT+5:30
# 9033281629      2022/04/10 7:42:16 PM GMT+5:30
# 8806996936      2022/04/11 8:41:38 PM GMT+5:30
# 7738554123      2022/04/11 8:48:50 PM GMT+5:30
#
#                                      Username                      Name  \
# Mobile number
# 7058925952          suvarnasonone60@gmail.com   Suvarna Tathagat Sonone
# 7721911892                 smoregpp@gmail.com       More Sweety Rajaram
# 8770219283          janghelsakshi08@gmail.com            Sakshi Janghel
# 7741046470            punekarpayalv@gmail.com  Payal Vijaykumar Punekar
# ...

# %%
cdf.drop_duplicates(inplace=True)

# %%
cdf.describe()
# Out:
#                 PRN     marks
# count  1.000000e+01  10.00000
# mean   1.542381e+11   7.80000
# std    1.064344e+11   1.47573
# min    1.800000e+01   5.00000
# 25%    5.508504e+10   7.25000
# 50%    2.203401e+11   8.00000
# 75%    2.203401e+11   8.75000
# max    2.203401e+11  10.00000

# %%
cdf.mean()
# Out:
# /tmp/ipykernel_10176/2042048433.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cdf.mean()
# PRN      1.542381e+11
# marks    7.800000e+00
# dtype: float64

# %%
cdf.isnull()
# Out:
#                Timestamp  Username   Name  Email    PRN  marks
# Mobile number
# 7058925952         False     False  False  False  False  False
# 7721911892         False     False  False  False  False  False
# 8770219283         False     False  False  False  False  False
# 7741046470         False     False  False  False  False  False
# 9284180136         False     False  False  False  False  False
# 8208356103         False     False  False  False  False  False
# 9552881797         False     False  False  False  False  False
# 9033281629         False     False  False  False  False  False
# 8806996936         False     False  False  False  False  False
# 7738554123         False     False  False  False  False  False

# %%
cdf.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10176/2795562666.py in <module>
# ----> 1 cdf.fillna()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5174         downcast=None,
#    5175     ) -> DataFrame | None:
# -> 5176         return super().fillna(
#    5177             value=value,
#    5178             method=method,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6311         """
# ...

# %%
for col in cdf:#Iteration thourgh dataframe columns
    print(col)

# %%
cdf["Timestamp"]

# %%
cdf["Name"]

# %%
cdf.to_csv("exported_class.csv") 
cdf.to_json("exported_class.json")

# %%
import matplotlib.pyplot as plt

# %%
cdf.plot(kind="bar",x="Timestamp",y="marks",title="Assessment")

# %%
df = pd.DataFrame([[10,20],[30,50],[10,30]],index=["First","Second","Third"])
df

# %%
pd.DataFrame(cdf["Name"])

# %%
df=pd.DataFrame({"Col1":[1,2,3,4],"Col2":[3,4,5,5]})
df

# %%
df=pd.DataFrame({"Name":cdf["Name"],"Marks":cdf["marks"]})
df
df.info()

# %%
import matplotlib.pyplot as plt
df.plot(kind="bar",x="Name", y="Marks",title="Students Marks")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10176/37016608.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 df.plot(kind="bar",x="Name", y="Marks",title="Students Marks")
#
# NameError: name 'df' is not defined

# %%
covid_df =  pd.read_csv("covid.csv")

# %%
covid_df
# Out:
#        Date.Day  Date.Month  Date.Year  Data.Cases  Data.Deaths  \
# 0            31          12       2019           0            0
# 1            31          12       2019           0            0
# 2            31          12       2019           0            0
# 3            31          12       2019           0            0
# 4            31          12       2019           0            0
# ...         ...         ...        ...         ...          ...
# 53624        10          12       2020         202           16
# 53625        11          12       2020          63           10
# 53626        12          12       2020         113           11
# 53627        13          12       2020         298            9
# 53628        14          12       2020         746            6
#
#       Location.Country Location.Code  Data.Population Location.Continent
# 0          Afghanistan           AFG         38041757               Asia
# ...

# %%
import matplotlib.pyplot as plt
covid_df.plot(kind="scatter",x="Date.Month",y="Data.Deaths",title="Covid Data")
# Out:
# <AxesSubplot:title={'center':'Covid Data'}, xlabel='Date.Month', ylabel='Data.Deaths'>

# %%
import seaborn as sb

# %%
sb.displot(data=covid_df, x="Date.Day",y="Data.Deaths",rug=True)

# %%
import pandas as pd
import seaborn as sb
air_df = pd.read_csv("airlines.csv")
sb.displot(data=air_df, x="Airport.Code",y="Delays.Carrier",rug=True)

# %%
sb.catplot(x="Airport.Code", y="Delays.Carrier", data=air_df);

# %%
# !pip install plotly
# Out:
# ...
#      |████████████████████████████████| 28.8 MB 7.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
pd.options.plotting.backend="plotly"
air_df = pd.read_csv("airlines.csv")
gph=air_df.plot.scatter(x="Airport.Code", y="Delays.Carrier")
gph.show()
# Out:
# <div>                            <div id="b61e6dbe-2ff2-4717-997d-98dd7577b384" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b61e6dbe-2ff2-4717-997d-98dd7577b384")) {                    Plotly.newPlot(                        "b61e6dbe-2ff2-4717-997d-98dd7577b384",                        [{"hovertemplate":"Airport.Code=%{x}<br>Delays.Carrier=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["ATL","BOS","BWI","CLT","DCA","DEN","DFW","DTW","EWR","FLL","IAD","IAH","JFK","LAS","LAX","LGA","MCO","MDW","MIA","MSP","ORD","PDX","PHL","PHX","SAN","SEA","SFO","SLC","TPA","ATL","BOS","BWI","CLT","DCA","DEN","DFW","DTW","EWR","FLL","IAD","IAH","JFK","LAS","LAX","LGA","MCO","
# ...
